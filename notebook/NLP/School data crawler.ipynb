# %%
# !apt-get -y install google-chrome-stable
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   adwaita-icon-theme dconf-gsettings-backend dconf-service fontconfig
#   fonts-liberation glib-networking glib-networking-common
#   glib-networking-services gsettings-desktop-schemas gtk-update-icon-cache
#   hicolor-icon-theme humanity-icon-theme libauthen-sasl-perl libcairo-gobject2
#   libcairo2 libcolord2 libcroco3 libdata-dump-perl libdatrie1 libdconf1
#   libencode-locale-perl libepoxy0 libfile-basedir-perl
#   libfile-desktopentry-perl libfile-listing-perl libfile-mimeinfo-perl
#   libfont-afm-perl libgbm1 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgtk-3-0 libgtk-3-bin libgtk-3-common
#   libhtml-form-perl libhtml-format-perl libhtml-parser-perl
#   libhtml-tagset-perl libhtml-tree-perl libhttp-cookies-perl
#   libhttp-daemon-perl libhttp-date-perl libhttp-message-perl
# ...

# %%
chrome_driver_version = !curl -get http://chromedriver.storage.googleapis.com/LATEST_RELEASE
chrome_driver_version = chrome_driver_version[-1]
url = f'http://chromedriver.storage.googleapis.com/{chrome_driver_version}/chromedriver_linux64.zip'
url
# Out:
# 'http://chromedriver.storage.googleapis.com/98.0.4758.102/chromedriver_linux64.zip'

# %%
# !wget -O /tmp/chromedriver.zip $url
# Out:
# --2022-02-27 13:43:02--  http://chromedriver.storage.googleapis.com/98.0.4758.102/chromedriver_linux64.zip
# Resolving chromedriver.storage.googleapis.com (chromedriver.storage.googleapis.com)... 34.64.4.112, 2404:f340:10:1803::2010
# Connecting to chromedriver.storage.googleapis.com (chromedriver.storage.googleapis.com)|34.64.4.112|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10229802 (9.8M) [application/zip]
# Saving to: ‘/tmp/chromedriver.zip’
#
# /tmp/chromedriver.z 100%[===================>]   9.76M  8.69MB/s    in 1.1s
#
# 2022-02-27 13:43:04 (8.69 MB/s) - ‘/tmp/chromedriver.zip’ saved [10229802/10229802]

# %%
# !unzip /tmp/chromedriver.zip chromedriver -d /usr/local/bin/
# Out:
# Archive:  /tmp/chromedriver.zip
#   inflating: /usr/local/bin/chromedriver

# %% [markdown]
# https://stackoverflow.com/a/53626528/7270469

# %%
import pandas as pd 
import os
from hanspell import spell_checker
import requests
from urllib import parse
import json
from multiprocessing import Process, Queue, Pool, Manager
import math
import re
from time import process_time, sleep
from ckonlpy.tag import Twitter
from nltk import ngrams
from os import getpid
from selenium import webdriver
from IPython import display
from base64 import b64decode

# %%
options = webdriver.chrome.options.Options()
options.add_argument("--no-sandbox")
options.add_argument("--disable-setuid-sandbox")
options.add_argument("--disable-extensions")
options.add_argument('headless')
options.add_argument('window-size=1920x1080')
options.add_argument("disable-gpu")
driver = webdriver.Chrome(chrome_options=options)

driver.get("https://httpstat.us/200")

if "200 OK" in driver.page_source:
    print('Selenium successfully opened with Chrome (under the Xvfb display) and navigated to "https://httpstat.us/200", you\'re all set!')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: use options instead of chrome_options
# Selenium successfully opened with Chrome (under the Xvfb display) and navigated to "https://httpstat.us/200", you're all set!

# %%
driver.get('https://web.kangnam.ac.kr/menu/f19069e6134f8f8aa7f689a4a675e66f.do?paginationInfo.currentPageNo=1&searchMenuSeq=0&searchType=&searchValue=')

# %%
assert driver.page_source is not None

# %%
noticeTable = driver.find_element_by_css_selector('#sub_content_wrap > div > div > div.col-xs-12.col-md-9 > div > div.cont > div > div > div.ul_respon.tbl_num01.devTable')
display.Image(b64decode(noticeTable.screenshot_as_base64))

# %% [markdown]
# https://web.kangnam.ac.kr/menu/board/info/f19069e6134f8f8aa7f689a4a675e66f.do?scrtWrtiYn=false&encMenuSeq=41c4ba211ab06cbc003455e07441b4f8&encMenuBoardSeq=829e87ae5f6b09c3dcf0ff01fc1fabfd

# %%
for noticeRow in noticeList:
    try:
        li_list = noticeRow.find_elements_by_css_selector('li')
        if li_list[0].text.isdigit():
            aTag = noticeRow.find_element_by_css_selector('a')
            if aTag is not None:
                print(noticeRow.text, '\n==========================')
                print(json.loads(aTag.get_attribute('data-params')))
    except Exception as e:
        print(e)
# Out:
# 5295
# [교외_신청] 2022년 1학기「농림축산식품부 장학금」장학생 추가선발 공고
# 장학
# 장학복지팀
# 22.02.25
# 483
# ...
# {'scrtWrtiYn': False, 'encMenuSeq': '41c4ba211ab06cbc003455e07441b4f8', 'encMenuBoardSeq': '829e87ae5f6b09c3dcf0ff01fc1fabfd'}
# 5294
# [교무] 2022-1학기 온라인 수업 지원을 위한 전산실습실 운영 안내
# 학사
# -
# 교무팀
# 22.02.25
# 1,754
# ...
# {'scrtWrtiYn': False, 'encMenuSeq': 'c5dc4b1d7b4dd402e5e6a7a8471eb55c', 'encMenuBoardSeq': '45be650198273e34b1ce92749b27daad'}
# 5293
# [교무] 2022학년도 신입생 기초교양 수준별 반편성 및 직권수강신청 확인 방법 안내
# 학사
# 교무팀
# 22.02.25
# 2,503
# ...
# {'scrtWrtiYn': False, 'encMenuSeq': 'c5dc4b1d7b4dd402e5e6a7a8471eb55c', 'encMenuBoardSeq': '12a021a5fd5e1f8e19c0202a3f7b6ad0'}
# 5292
# 2022학년도 1학기 강사 4차 초빙
# 학사
# 인사팀
# 22.02.25
# 513
# ...
# {'scrtWrtiYn': False, 'encMenuSeq': 'c5dc4b1d7b4dd402e5e6a7a8471eb55c', 'encMenuBoardSeq': '68c9308c935963a95399d9acde028e52'}
# 5291
# [교무] 2022-1학기 1차 합반 및 폐강 교과목 추가 및 수강변경 방법 안내
# 학사
# 교무팀
# 22.02.24
# 3,349
# ...

# %%
noticeList = noticeTable.find_elements_by_css_selector('ul')

# %%
response = requests.get('https://web.kangnam.ac.kr/menu/board/info/f19069e6134f8f8aa7f689a4a675e66f.do', \
                        params={'scrtWrtiYn': False, 'encMenuSeq': '41c4ba211ab06cbc003455e07441b4f8', 'encMenuBoardSeq': '829e87ae5f6b09c3dcf0ff01fc1fabfd'})

response.status_code
# Out:
# 200

# %%
query = parse.urlencode({'scrtWrtiYn': False, 'encMenuSeq': '41c4ba211ab06cbc003455e07441b4f8', 'encMenuBoardSeq': '829e87ae5f6b09c3dcf0ff01fc1fabfd'})
url = f'https://web.kangnam.ac.kr/menu/board/info/f19069e6134f8f8aa7f689a4a675e66f.do?{query}'
url
# Out:
# 'https://web.kangnam.ac.kr/menu/board/info/f19069e6134f8f8aa7f689a4a675e66f.do?scrtWrtiYn=False&encMenuSeq=41c4ba211ab06cbc003455e07441b4f8&encMenuBoardSeq=829e87ae5f6b09c3dcf0ff01fc1fabfd'

# %%
driver.get(url)

# %%
content = driver.find_element_by_css_selector('#sub_content_wrap > div > div > div.col-xs-12.col-md-9 > div > div.cont > div > div > div.ul_respon.tbl_wtite.tbl_write02 > div.tbody > ul:nth-child(2) > li > div')
content.text.split('\n')
# Out:
# ['2022년 1학기「농림축산식품부 장학금」장학생 추가선발 공고',
#  ' 2022년 1학기 농림축산식품부 장학금 중 「청년창업농육성장학생」을 다음과 같이 선발하고자 하니 대학생 여러분의 많은 참여를 바랍니다.',
#  '  1. 청년창업농육성장학금',
#  '□ 지원내용 : 매학기 장학금(등록금 전액 + 학업장려금 200만원)',
#  '    - 장학금(등록금+학업장려금)은 전액 지급이 원칙이나, 타 장학금을 이미 수혜받은 경우, 등록금 범위 내에서',
#  '      그 금액을 제외하고 지원 (추가모집 기준)',
#  '    ※ 단, 타 장학금으로 등록금 전액 수혜자는 신청 불가',
#  '□ 지원대상(자격요건)',
#  '<신규자>',
#  '  - 농업계대학 농식품계열학과* 및 비농업계대학 재학생    * 지원대상 대학·학과, 안내서 참고',
#  '  - 일반대 3학년 이상(3학년 1학기 진학 예정자 포함)',
#  '  - 시행년도(2022.1.1.) 기준 만40세 미만(1982.1.1.이후 출생자)',
#  '  - 직전학기 성적(백분위 점수) 70점, 12학점 이상 이수자',
#  '<계속자>',
#  '  - 직전학기 성적(백분위 점수) 70점, 12학점 이상 이수자',
#  '  - 의무교육 25시간이상 이수자',
#  '□ 선발규모 : 총 345명 내외',
#  '□ 최대지원학기',
#  '  - 일반대 : 최대 4학기',
#  '  - 전문대 : 최대 3학기(전공심화과정 진학 시 최대 4학기)',
#  '□ 지원조건 : 졸업 후 장학금 수혜 횟수에 해당하는 기간만큼(수혜 학기당 6개월) 영농 및 농림축산식품 분야에',
#  '    취업 또는 창업하여 의무종사',
#  '□ 심사·선발 절차 :  신청 → 대학교 추천→ 서류심사 → 보증보험가입 → 최종선발',
#  '□ 신청기간 : 2022. 2. 28.(월) 10:00 ~ 3. 15.(화) 17:00 까지',
# ...

# %%
content.get_attribute('innerHTML')
# Out:
# '<div class="tbl_view cke_editable cke_editable_themed cke_contents_ltr"><p class="contents_add_one1" style="display:none;">농림축산식품부</p><p class="contents_add_one2" style="display:none;">청년창업농육성장학생</p><p>2022년 1학기「농림축산식품부 장학금」장학생 추가선발 공고</p><p>&nbsp;</p><p>2022년 1학기 농림축산식품부 장학금 중 「청년창업농육성장학생」을 다음과 같이 선발하고자 하니 대학생 여러분의 많은 참여를 바랍니다.</p><p>&nbsp;</p><p>&nbsp;</p><table class="table"><tbody><tr class="first last"><td style="width:639px;height:41px;" class="first last tdLowOne"><p>1. 청년창업농육성장학금</p></td></tr></tbody></table><p>□ 지원내용 : 매학기 장학금(등록금 전액 + 학업장려금 200만원)</p><p>&nbsp; &nbsp; -&nbsp;장학금(등록금+학업장려금)은 전액 지급이 원칙이나, 타 장학금을 이미 수혜받은 경우, 등록금 범위 내에서</p><p>&nbsp; &nbsp; &nbsp; 그 금액을 제외하고 지원 (추가모집 기준)</p><p>&nbsp; &nbsp; ※ 단, 타 장학금으로 등록금 전액 수혜자는 신청 불가</p><p>□ 지원대상(자격요건)</p><p>&lt;신규자&gt;</p><p>&nbsp; -&nbsp;농업계대학 농식품계열학과* 및 비농업계대학 재학생&nbsp; &nbsp; * 지원대상 대학·학과, 안내서 참고</p><p>&nbsp; - 일반대 3학년 이상(3학년 1학기 진학 예정자 포함)</p><p>&nbsp; - 시행년도(2022.1.1.) 기준 만40세 미만(1982.1.1.이후 출생자)</p><p>&nbsp; -&nbsp;직전
# ...

# %%
display.Image(b64decode(content.screenshot_as_base64))

# %%
driver.get('https://web.kangnam.ac.kr/menu/board/info/f19069e6134f8f8aa7f689a4a675e66f.do?scrtWrtiYn=false&encMenuSeq=c5dc4b1d7b4dd402e5e6a7a8471eb55c&encMenuBoardSeq=1db853c16158bdae31c09d146d4571dc')

# %%
content = driver.find_element_by_css_selector('#sub_content_wrap > div > div > div.col-xs-12.col-md-9 > div > div.cont > div > div > div.ul_respon.tbl_wtite.tbl_write02 > div.tbody > ul:nth-child(2) > li > div')
img_list = content.find_elements_by_css_selector('img')

# %%
for img in img_list:
    if 'base64' in img.get_attribute('src'):
#         print(re.search(r'base64,(.*)', img.get_attribute('src')).group(1), "\n\n")
        display.Image(b64decode(re.search(r'base64,(.*)', img.get_attribute('src')).group(1)))
    else:
        print(img.get_attribute('src'))

# %%
display.Image(b64decode(re.search(r'base64,(.*)', img_list[0].get_attribute('src')).group(1)))
